# %% [markdown]
# <a href="https://colab.research.google.com/github/chaymabaya/reconnaissace-faciale/blob/main/reconnaissance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
img= cv2.imread('happy1.jpg')
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 32.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.3 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=106e03b61648599e0f460725bd49863c3682e4b5f3425796d32d7f02ace0127c
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...

# %%
from deepface import DeepFace
# Out:
# 25-04-15 20:55:02 - Directory /root/.deepface has been created
# 25-04-15 20:55:02 - Directory /root/.deepface/weights has been created

# %%
predections = DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 25-04-15 20:55:36 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
#
#   0%|          | 0.00/5.98M [00:00<?, ?B/s]
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 39.0MB/s]
# Action: age:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/it]
# 25-04-15 20:55:39 - age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
#
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   2%|▏         | 11.0M/539M [00:00<00:05, 103MB/s]
#   6%|▌         | 30.4M/539M [00:00<00:03, 155MB/s]
#   9%|▊         | 46.1M/539M [00:00<00:03, 130MB/s]
#  14%|█▎        | 73.9M/539M [00:00<00:02, 178MB/s]
# ...

# %%
perdactions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  2.00it/s]

# %%
perdactions[0]['dominant_emotion']
# Out:
# 'neutral'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
Faces = faceCascade.detectMultiScale(gray, 1.1,4)
for (x,y,w,h) in Faces: # Removed the extra space before 'for'
    cv2.rectangle(img, (x,y) , (x+w,y+h) , (0,255,0) , 2 )
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, perdactions[0]['dominant_emotion'], (500, 1000), font, 1, (255, 0, 255), 2, cv2.LINE_4)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
